# %%
import pandas as pd
from pandas import *
import numpy as np
import matplotlib.pyplot as plt

# %%
# THE USGS PROVIDES ON PAST EARTHQUAKES 

#FOR THIS ASSIGNMENT A csv file is taken from USGS website having details on all the
#Earthquakes happended in past 1 week worldwide.

# %%
data= pd.read_csv("USGS_5min.csv")

# %%
data
# Out:
# Empty DataFrame
# Columns: [time, latitude, longitude, depth, mag, magType, nst, gap, dmin, rms, net, id, updated, place, type]
# Index: []

# %%
#PAST 1 WEEK EARTHQUAKE DETAILS SPREAD SHEET
data= pd.read_csv("2.5_day.csv")
data
# Out:
#                         time   latitude   longitude   depth   mag magType  \
# 0   2015-12-02T19:40:30.200Z  36.812300  -98.270900   5.000  3.40   mb_lg
# 1   2015-12-02T17:51:10.990Z  19.382834 -155.237167   3.660  2.94      ml
# 2   2015-12-02T17:09:01.000Z  58.148600 -152.764400  70.500  2.80      ml
# 3   2015-12-02T14:29:50.300Z  19.489000  -64.358000  59.000  3.50      Md
# 4   2015-12-02T13:14:35.700Z  18.875700  -64.559300  14.000  3.20      Md
# 5   2015-12-02T12:12:39.700Z -16.796900  175.173300  66.180  4.70      mb
# 6   2015-12-02T10:20:48.470Z  36.821335 -121.549164   4.750  2.50      md
# 7   2015-12-02T10:08:29.680Z  -6.267800  154.673400  63.280  5.30      mb
# 8   2015-12-02T10:05:25.000Z  61.693800 -147.262900  35.800  4.60      ml
# 9   2015-12-02T10:02:15.660Z  35.973800   69.318700  41.350  4.50      mb
# 10  2015-12-02T10:00:51.000Z  -4.886400  152.517000  49.740  4.70      mb
# 11  2015-12-02T09:38:27.570Z -30.417700  -72.135500  10.000  4.80     mwr
# ...

# %%
newt = data[["place", "mag", "time"]]
newt
# Out:
#                                              place   mag  \
# 0                     9km NE of Cherokee, Oklahoma  3.40
# 1                         5km S of Volcano, Hawaii  2.94
# 2               43km NNW of Kodiak Station, Alaska  2.80
# 3   121km NNE of Road Town, British Virgin Islands  3.50
# 4      51km N of Road Town, British Virgin Islands  3.20
# 5                       260km WNW of Lautoka, Fiji  4.70
# 6         2km SSW of San Juan Bautista, California  2.50
# 7              89km W of Panguna, Papua New Guinea  5.30
# 8                        82km NW of Valdez, Alaska  4.60
# 9                  19km ESE of Nahrin, Afghanistan  4.50
# 10            65km SSE of Kokopo, Papua New Guinea  4.70
# 11                       91km WNW of Ovalle, Chile  4.80
# 12                  46km N of Isabela, Puerto Rico  2.80
# 13                        241km E of Yamada, Japan  4.80
# 14                        69km SW of Homer, Alaska  2.80
# ...

# %%
#PLACES WITH EARTHQUAKE GREATER THEN 3 IN LAST 1 WEEK
newt2=newt[(newt.mag >= 3)]
newt2
# Out:
#                                              place  mag  \
# 0                     9km NE of Cherokee, Oklahoma  3.4
# 3   121km NNE of Road Town, British Virgin Islands  3.5
# 4      51km N of Road Town, British Virgin Islands  3.2
# 5                       260km WNW of Lautoka, Fiji  4.7
# 7              89km W of Panguna, Papua New Guinea  5.3
# 8                        82km NW of Valdez, Alaska  4.6
# 9                  19km ESE of Nahrin, Afghanistan  4.5
# 10            65km SSE of Kokopo, Papua New Guinea  4.7
# 11                       91km WNW of Ovalle, Chile  4.8
# 13                        241km E of Yamada, Japan  4.8
# 16                     38km ENE of Hualian, Taiwan  4.7
# 18                     49km E of Ishinomaki, Japan  4.6
# 21    220km ESE of Pagan, Northern Mariana Islands  4.8
# 22                       66km SE of Ofunato, Japan  4.7
# 24             73km S of Panguna, Papua New Guinea  5.0
#
#                         time
# 0   2015-12-02T19:40:30.200Z
# ...

# %%
np.max(newt2,axis =1)
# Out:
# 0                     9km NE of Cherokee, Oklahoma
# 3                         2015-12-02T14:29:50.300Z
# 4      51km N of Road Town, British Virgin Islands
# 5                       260km WNW of Lautoka, Fiji
# 7              89km W of Panguna, Papua New Guinea
# 8                        82km NW of Valdez, Alaska
# 9                         2015-12-02T10:02:15.660Z
# 10            65km SSE of Kokopo, Papua New Guinea
# 11                       91km WNW of Ovalle, Chile
# 13                        241km E of Yamada, Japan
# 16                     38km ENE of Hualian, Taiwan
# 18                     49km E of Ishinomaki, Japan
# 21    220km ESE of Pagan, Northern Mariana Islands
# 22                       66km SE of Ofunato, Japan
# 24             73km S of Panguna, Papua New Guinea
# dtype: object

# %%
from __future__ import division

# %%
#STATISTICAL ANALYSIS OF DATA
data.describe()
# Out:
#         latitude   longitude      depth        mag        nst         gap  \
# count  25.000000   25.000000  25.000000  25.000000   8.000000   21.000000
# mean   27.378428  -12.154209  29.744560   3.770400  18.500000  151.357143
# std    24.780993  131.142062  23.829114   1.014563  19.302109   91.133575
# min   -30.417700 -155.237167   0.024000   2.500000   4.000000   34.000000
# 25%    18.875700 -121.549164  10.000000   2.800000   5.750000   91.000000
# 50%    36.728200  -67.011100  18.350000   3.500000   9.000000  133.000000
# 75%    40.284500  142.305600  53.320000   4.700000  24.500000  179.500000
# max    61.693800  175.173300  70.500000   5.300000  51.000000  324.000000
#
#             dmin        rms
# count  21.000000  25.000000
# mean    1.429012   0.597980
# std     1.885677   0.379472
# min     0.009773   0.070000
# 25%     0.211900   0.230000
# 50%     0.775000   0.630000
# 75%     1.448000   0.800000
# max     7.776000   1.590000

# %%
#totoal number of earthquakes happened in past 7 days
len(data["mag"])
# Out:
# 25

# %%
#Disply all the places where Earthquake happened:
places= pd.DataFrame(data["place"].unique(), columns=["All Affected areas"])
places
# Out:
#                                 All Affected areas
# 0                     9km NE of Cherokee, Oklahoma
# 1                         5km S of Volcano, Hawaii
# 2               43km NNW of Kodiak Station, Alaska
# 3   121km NNE of Road Town, British Virgin Islands
# 4      51km N of Road Town, British Virgin Islands
# 5                       260km WNW of Lautoka, Fiji
# 6         2km SSW of San Juan Bautista, California
# 7              89km W of Panguna, Papua New Guinea
# 8                        82km NW of Valdez, Alaska
# 9                  19km ESE of Nahrin, Afghanistan
# 10            65km SSE of Kokopo, Papua New Guinea
# 11                       91km WNW of Ovalle, Chile
# 12                  46km N of Isabela, Puerto Rico
# 13                        241km E of Yamada, Japan
# 14                        69km SW of Homer, Alaska
# 15                    28km E of Cherokee, Oklahoma
# 16                     38km ENE of Hualian, Taiwan
# ...

# %%
newdata = data[data["place"]=="2km SSW of San Juan Bautista, California"].sort("mag")
newdata
# Out:
# C:\Users\PERSONAL\myvagrant\Anaconda2\lib\site-packages\ipykernel\__main__.py:1: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#   if __name__ == '__main__':
#                        time   latitude   longitude  depth  mag magType  nst  \
# 6  2015-12-02T10:20:48.470Z  36.821335 -121.549164   4.75  2.5      md   47
#
#    gap     dmin   rms net          id                   updated  \
# 6   34  0.02887  0.07  nc  nc72563276  2015-12-02T18:23:54.286Z
#
#                                       place        type
# 6  2km SSW of San Juan Bautista, California  earthquake

# %%
#Counting how many times each Earthquake magnitude ouccured
newdata = data["mag"].value_counts()
newdata
# Out:
# 2.80    4
# 4.70    4
# 4.80    3
# 2.50    3
# 4.60    2
# 2.60    1
# 2.72    1
# 5.00    1
# 3.40    1
# 3.20    1
# 5.30    1
# 4.50    1
# 2.94    1
# 3.50    1
# Name: mag, dtype: int64

# %%
#DATA with magnitude grater than 4
newdata = data[data["mag"] >= 4].sort("place")
newdata
# Out:
# C:\Users\PERSONAL\myvagrant\Anaconda2\lib\site-packages\ipykernel\__main__.py:2: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#   from ipykernel import kernelapp as app
#                         time  latitude  longitude  depth  mag magType  nst  \
# 9   2015-12-02T10:02:15.660Z   35.9738    69.3187  41.35  4.5      mb  NaN
# 21  2015-12-02T00:51:47.470Z   17.1547   147.5980  10.00  4.8      mb  NaN
# 13  2015-12-02T06:48:06.660Z   39.0406   144.6888  17.64  4.8      mb  NaN
# 5   2015-12-02T12:12:39.700Z  -16.7969   175.1733  66.18  4.7      mb  NaN
# 16  2015-12-02T05:21:57.650Z   24.1464   121.9340  18.35  4.7      mb  NaN
# 18  2015-12-02T04:41:19.640Z   38.4043   141.8714  59.30  4.6      mb  NaN
# 10  2015-12-02T10:00:51.000Z   -4.8864   152.5170  49.74  4.7      mb  NaN
# 22  2015-12-01T22:48:06.410Z   38.6922   142.3056  30.05  4.7      mb  NaN
# 24  2015-12-01T20:20:12.730Z   -6.9813   155.5593  53.32  5.0      mb  NaN
# ...

# %%
#Statistical analysis of mag
result =newdata.describe()

result["mag"]
# Out:
# count    12.000000
# mean      4.766667
# std       0.210339
# min       4.500000
# 25%       4.675000
# 50%       4.700000
# 75%       4.800000
# max       5.300000
# Name: mag, dtype: float64
